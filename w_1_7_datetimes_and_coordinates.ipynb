# %% [markdown]
# # Datetime

# %% [markdown]
# Generation of possible variables with Dates:

# %% [markdown]
# ## 1) Datetime Periodicity

# %% [markdown]
# Number of day, number of month, particle of seconds, etc. These variables help achieve and capture periodicity effects.

# %% [markdown]
# ## 2) Time since a specific event

# %% [markdown]
# Current time - date<br>
# Time that has passed since last purchase, Number of days left to an event<br>

# %% [markdown]
# This type of variable can be row dependent or row independent:<br>
#     Row dependent: difference of 2 dates in data set (difference of 2 date cells in table)<br>
#     Row independent: specific date outside data set or constant - date in a cell of the row.

# %% [markdown]
# ## 3) Date Binary Condition

# %% [markdown]
# Is it weekday, is it weekend, is it holiday? Different types of questions that can be answerd binarily (0,1) regarding the date.

# %%
from IPython.display import Image
Image(filename="C:/ANIBAL/FORMATION/PERSONAL/how_to_win_a_data_science_competition/images/cal1.png")

# %% [markdown]
# ## 4) Difference between dates

# %% [markdown]
# It can be converted into numeric. Like different between 2 dates converted into minutes, seconds or hours.

# %%
Image(filename="C:/ANIBAL/FORMATION/PERSONAL/how_to_win_a_data_science_competition/images/dt1.png")

# %% [markdown]
# # Coordinates

# %% [markdown]
# We lack this part. Please fulfill seeing the course. Focusing on a tetra pak ML problem with table data.
